# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {schema}")
spark.sql(f"USE SCHEMA {schema}")
print(catalog)
print(schema)
# Out:
# bakehouse_analytics_dev
# rnd

# %%
spark.sql(f"""CREATE OR REPLACE TABLE bakehouse_analytics_dev.rnd.franchise_analytics AS
SELECT country, size, COUNT(*) AS number_of_franchise
FROM samples.bakehouse.sales_franchises 
GROUP BY country, size""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]
